# %% [markdown]
# To create a new project, you can start by defining the scope and objectives of your project. This typically involves identifying the data sources you'll be using, the analyses you plan to perform, and the tools or technologies you'll need. Once you have a clear plan, you can set up a new environment or workspace, such as a new notebook or repository, where you can organize your data, code, and results.
#
# If you need assistance with specific steps or tasks within your project, feel free to ask!

# %%
# !pip install flask==2.3.3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.1/96.1 kB 9.3 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

data = pd.read_csv('therapist_pool.csv')
data
# Out:
#    firstName   lastName  postCode                     city             gender  \
# 0      Elara  Sternfels      8001         Zürich (Central)             Female
# 1     Mathis     Dupont      1003       Lausanne (Central)               Male
# 2      Linus     Amrein      6000         Lucerne (Luzern)         Non-binary
# 3     Chiara   Bärtschi      3000             Bern (Berne)             Female
# 4     Pascal       Frey      4058                    Basel               Male
# 5      Heidi     Zeller      9000               St. Gallen         Non-binary
# 6      Silas      Weber      5000                    Aarau             Female
# 7      Adèle   Girardin      2500              Biel/Bienne               Male
# 8       Gian   Caminada      7000                     Chur  Prefer not to say
# 9      Leana       Koch      8400               Winterthur             Female
# 10   Antoine      Rossi      1200          Genève (Geneva)               Male
# ...

# %% [markdown]
# <hr>

# %%
from datetime import datetime, timedelta, time

def next_week_weekday():
    d = datetime.now().date() + timedelta(weeks=1) # could be adjusted to waiting time

    if d.weekday() == 5:
        d += timedelta(days=2)
    elif d.weekday() == 6:
        d += timedelta(days=1)

    return datetime.combine(d, time(hour=14)) # adjust to use 08:00 in the morning, 14:00 in the afternoon


def get_selected_therapist_and_datetime():
    therapist = 'Dr. Smith' # ideally this would be a random selections of the suggested therapists
    datetime = next_week_weekday()
    
    return {
        'therapist': therapist,
        'datetime': datetime.isoformat() 
    }

# %%
import random

def weighted_random_answer():
    choices = ['yes', 'no']
    
    # weights must sum up to an arbitrary total (e.g., 10 or 100). --> here 70% yes, 30% no
    weights = [7, 3] 
    result = random.choices(choices, weights=weights, k=1)
    
    return result[0]

# %%
def fuse_name(name: str) -> str:
    parts = name.split(' ')
    fused = ''.join(part.replace('.', '') for part in parts)
    return fused.lower()

def create_email_address(name: str) -> str:
    return fuse_name(name) + '@chocolat.com'

def send_fake_email(to, subject, body):
    EMAIL_LOG = []
    EMAIL_LOG.append({
        "to": to,
        "subject": subject,
        "body": body
    })
    print(f"[EMAIL SIMULATED] to={to} subject={subject} body={body}") 


def send_therapist_suggestions_list(payload):
    print(payload)
    send_fake_email('patient@chocolat.com', 'Therapist suggestions', 'Here are your therapist suggestions')
    print('sending list to patient')


def send_messages_to_recipients(payload):
    subject = 'Therapy Appointment Details'
    patient_address = create_email_address('patient') # use actual patient name
    therapist_address = create_email_address('Dr. Smith') # use actual therapist name

    send_fake_email('patient@chocolat.com', subject, 'ABC details') # use the data for the appointment details
    send_fake_email('therapist@chocolat.com', subject, 'apointment details') # use the data for the appointment details

# %% [markdown]
# Create endpoints

# %%
from flask import Flask, jsonify, request

app = Flask(__name__)
MATCH_MAKER = '/therapist-matcher'


@app.route(MATCH_MAKER + "/therapists-suggestion", methods=["POST"])
def send_therapist_list():
    payload = request.get_json(force=True, silent=True) or {}
    send_therapist_suggestions_list(payload)
    return jsonify({"status": "success", "message": "Message sent successfully."}), 200

@app.route(MATCH_MAKER + "/selection", methods=["GET"])
def handle_selection_request():
    result = get_selected_therapist_and_datetime()
    return jsonify(result)

@app.route(MATCH_MAKER + "/send-message", methods=["POST"])
def send_message():
    payload = request.get_json(force=True, silent=True) or {}
    result = send_messages_to_recipients(payload)
    return jsonify({"status": "success", "message": "Message sent successfully."}), 200

@app.route(MATCH_MAKER + "/therapist-response", methods=["GET"])
def get_therapis_response():
    answer = weighted_random_answer()
    print(answer)
    return answer

@app.route(MATCH_MAKER + "/")
def ehr_app():
    return 'The Therapist Matcher Server is running.'

# %% [markdown]
# Run it

# %%
# the following line of code will make this notebook act like a server
app.run(host='0.0.0.0', port=8080)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[66], line 2
#       1 # the following line of code will make this notebook act like a server
# ----> 2 start_fake_smtp()
#       3 app.run(host='0.0.0.0', port=5000)
#
# Cell In[48], line 6, in start_fake_smtp()
#       5 def start_fake_smtp():
# ----> 6     server = smtpd.DebuggingServer(('localhost', 1025), None)
#       7     thread = threading.Thread(target=asyncore.loop, daemon=True)
#       8     thread.start()
#
# File /usr/local/lib/python3.11/smtpd.py:653, in SMTPServer.__init__(self, localaddr, remoteaddr, data_size_limit, map, enable_SMTPUTF8, decode_data)
#     651     # try to re-use a server port if possible
#     652     self.set_reuse_addr()
# --> 653     self.bind(localaddr)
#     654     self.listen(5)
#     655 except:
#
# File /usr/local/lib/python3.11/asyncore.py:331, in dispatcher.bind(self, addr)
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=fbdcce36-fd51-4cfb-8676-e6e544158098' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
